# %% [markdown]
# <a href="https://colab.research.google.com/github/luna999-ai/unidad3/blob/main/practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Plotting sin linea. Para trazar solo los marcadores, puedes usar notacion de cadena de acceso directo 'o', que significa "anillos". Ejemplo:Dibuja dos puntos en el diagrama, uno en la posicion (1,3) y otro en la posicion (8,10)

# %%
import matolotlib.pyplot as plt
import numpy as np

puntosX = np.array([1,8])
puntosY = np.array([3,10])

plt.plot(puntosX,puntosY, 'o')
plt.show()

# %% [markdown]
# diagramas de dispersion (scatter)
#
# se emplea para mostrar la relacion entre dos variables numericas, detectando correlaciones o agrupamientos
# Ejemplo:

# %%
import matplotlib.pyplot as plt

altura=[150,160,170,180,190,200]
peso=[50,60,65,80,85,95]

plt.scatter(altura,peso,color = "red", marker = "x")
plt.title("relacion entre alrura y peso")
plt.xlabel("altura (cms)")
plt.ylable("peso (kg)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2513016198.py in <cell line: 0>()
#       7 plt.title("relacion entre alrura y peso")
#       8 plt.xlabel("altura (cms)")
# ----> 9 plt.ylable("peso (kg)")
#      10 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %% [markdown]
# Graficos de barras (bar y barh)
# Sirve para comparar categorias o variables tanto en orientacion vertical como horizontal.
# Ejemplo de barras vertical:

# %%
import matplotlib.pyplot as plt

categorias = ["A", "B", "C", "D"]
valores = [4,7,1,8]

plt.bar(categorias, valores, color = "orange")
plt.title("graficas de barras")
plt.xlabel("categorias")
plt.ylabel("valores")
plt.show()
